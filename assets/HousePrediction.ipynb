# %%
import pandas as pd
import numpy as np

dataset=pd.read_csv('data.csv')
print(dataset)
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
dataset=dataset.drop(['date','sqft_lot','waterfront','view','condition','sqft_above','sqft_basement','street','statezip','country'],axis=1)
print(dataset)
# Out:
#              price  bedrooms  bathrooms  sqft_living  floors  yr_built  \
# 0     3.130000e+05       3.0       1.50         1340     1.5      1955
# 1     2.384000e+06       5.0       2.50         3650     2.0      1921
# 2     3.420000e+05       3.0       2.00         1930     1.0      1966
# 3     4.200000e+05       3.0       2.25         2000     1.0      1963
# 4     5.500000e+05       4.0       2.50         1940     1.0      1976
# ...            ...       ...        ...          ...     ...       ...
# 4595  3.081667e+05       3.0       1.75         1510     1.0      1954
# 4596  5.343333e+05       3.0       2.50         1460     2.0      1983
# 4597  4.169042e+05       3.0       2.50         3010     2.0      2009
# 4598  2.034000e+05       4.0       2.00         2090     1.0      1974
# 4599  2.206000e+05       3.0       2.50         1490     2.0      1990
#
#       yr_renovated       city
# 0             2005  Shoreline
# 1                0    Seattle
# ...

# %%
data2=dataset['price']
print(data2)

dataset=dataset.drop(['price'],axis=1)
print(dataset)

dataset['Price']=data2
print(dataset)
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64
#       bedrooms  bathrooms  sqft_living  floors  yr_built  yr_renovated  \
# 0          3.0       1.50         1340     1.5      1955          2005
# 1          5.0       2.50         3650     2.0      1921             0
# 2          3.0       2.00         1930     1.0      1966             0
# 3          3.0       2.25         2000     1.0      1963             0
# 4          4.0       2.50         1940     1.0      1976          1992
# ...        ...        ...          ...     ...       ...           ...
# 4595       3.0       1.75         1510     1.0      1954          1979
# 4596       3.0       2.50         1460     2.0      1983          2009
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

dataset.city=le.fit_transform(dataset.city)
print(dataset)
# Out:
#       bedrooms  bathrooms  sqft_living  floors  yr_built  yr_renovated  city  \
# 0          3.0       1.50         1340     1.5      1955          2005    36
# 1          5.0       2.50         3650     2.0      1921             0    35
# 2          3.0       2.00         1930     1.0      1966             0    18
# 3          3.0       2.25         2000     1.0      1963             0     3
# 4          4.0       2.50         1940     1.0      1976          1992    31
# ...        ...        ...          ...     ...       ...           ...   ...
# 4595       3.0       1.75         1510     1.0      1954          1979    35
# 4596       3.0       2.50         1460     2.0      1983          2009     3
# 4597       3.0       2.50         3010     2.0      2009             0    32
# 4598       4.0       2.00         2090     1.0      1974             0    35
# 4599       3.0       2.50         1490     2.0      1990             0     9
#
#              Price
# 0     3.130000e+05
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

ct=ColumnTransformer([("city",OneHotEncoder(),[6])],remainder = 'passthrough')
dataset=ct.fit_transform(dataset)
print(dataset)
# Out:
#   (0, 36)	1.0
#   (0, 44)	3.0
#   (0, 45)	1.5
#   (0, 46)	1340.0
#   (0, 47)	1.5
#   (0, 48)	1955.0
#   (0, 49)	2005.0
#   (0, 50)	313000.0
#   (1, 35)	1.0
#   (1, 44)	5.0
#   (1, 45)	2.5
#   (1, 46)	3650.0
#   (1, 47)	2.0
#   (1, 48)	1921.0
#   (1, 50)	2384000.0
#   (2, 18)	1.0
#   (2, 44)	3.0
#   (2, 45)	2.0
#   (2, 46)	1930.0
#   (2, 47)	1.0
#   (2, 48)	1966.0
#   (2, 50)	342000.0
#   (3, 3)	1.0
#   (3, 44)	3.0
#   (3, 45)	2.25
#   :	:
#   (4596, 47)	2.0
#   (4596, 48)	1983.0
#   (4596, 49)	2009.0
#   (4596, 50)	534333.333333
#   (4597, 32)	1.0
#   (4597, 44)	3.0
#   (4597, 45)	2.5
#   (4597, 46)	3010.0
#   (4597, 47)	2.0
#   (4597, 48)	2009.0
#   (4597, 50)	416904.166667
#   (4598, 35)	1.0
#   (4598, 44)	4.0
#   (4598, 45)	2.0
#   (4598, 46)	2090.0
#   (4598, 47)	1.0
#   (4598, 48)	1974.0
#   (4598, 50)	203400.0
#   (4599, 9)	1.0
#   (4599, 44)	3.0
#   (4599, 45)	2.5
#   (4599, 46)	1490.0
#   (4599, 47)	2.0
#   (4599, 48)	1990.0
#   (4599, 50)	220600.0

# %%
inputt=dataset[:,:-2]
print(input)

outputt=dataset[:,-1]
print(output)

print(inputt.shape)
print(outputt.shape)

# import tensorflow as tf
# inputt= tf.placeholder(tf.int32,[None,None])


# inputt=inputt.reshape(inputt.shape[1:])
# inputt=inputt.transpose()

# print(inputt.shape)
# Out:
#   (0, 36)	1.0
#   (0, 44)	3.0
#   (0, 45)	1.5
#   (0, 46)	1340.0
#   (0, 47)	1.5
#   (0, 48)	1955.0
#   (1, 35)	1.0
#   (1, 44)	5.0
#   (1, 45)	2.5
#   (1, 46)	3650.0
#   (1, 47)	2.0
#   (1, 48)	1921.0
#   (2, 18)	1.0
#   (2, 44)	3.0
#   (2, 45)	2.0
#   (2, 46)	1930.0
#   (2, 47)	1.0
#   (2, 48)	1966.0
#   (3, 3)	1.0
#   (3, 44)	3.0
#   (3, 45)	2.25
#   (3, 46)	2000.0
#   (3, 47)	1.0
#   (3, 48)	1963.0
#   (4, 31)	1.0
#   :	:
#   (4595, 48)	1954.0
#   (4596, 3)	1.0
#   (4596, 44)	3.0
#   (4596, 45)	2.5
#   (4596, 46)	1460.0
#   (4596, 47)	2.0
#   (4596, 48)	1983.0
#   (4597, 32)	1.0
#   (4597, 44)	3.0
#   (4597, 45)	2.5
#   (4597, 46)	3010.0
#   (4597, 47)	2.0
#   (4597, 48)	2009.0
#   (4598, 35)	1.0
#   (4598, 44)	4.0
#   (4598, 45)	2.0
#   (4598, 46)	2090.0
#   (4598, 47)	1.0
#   (4598, 48)	1974.0
#   (4599, 9)	1.0
#   (4599, 44)	3.0
#   (4599, 45)	2.5
#   (4599, 46)	1490.0
#   (4599, 47)	2.0
#   (4599, 48)	1990.0
#   (0, 0)	313000.0
#   (1, 0)	2384000.0
#   (2, 0)	342000.0
# ...

# %%
from sklearn.model_selection import train_test_split
input_train,input_test,output_train,output_test=train_test_split(inputt,outputt,test_size=0.2,random_state=0)

# %%
# from sklearn.linear_model import LinearRegression
# regressor = LinearRegression()  
# regressor.fit(input_train, output_train)


from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(max_depth = 5, random_state = 14)
model.fit(input_train, output_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'csc_matrix'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-240-d095a92ba94d> in <module>
#       6 from sklearn.ensemble import RandomForestRegressor
#       7 model = RandomForestRegressor(max_depth = 5, random_state = 14)
# ----> 8 model.fit(input_train, output_train)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     322
#     323         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
# --> 324             y = np.ascontiguousarray(y, dtype=DOUBLE)
#     325
#     326         if expanded_class_weight is not None:
#
# ...
